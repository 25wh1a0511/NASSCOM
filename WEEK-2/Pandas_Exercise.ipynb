# %% [markdown]
# <a href="https://colab.research.google.com/github/25wh1a0511/NASSCOM/blob/main/Pandas_Exercise.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np

print("--- Intermediate Pandas Exercise ---")
print("Complete each task by writing the requested Pandas code.")
print("------------------------------------")

# Task 1: Basic Pandas Functions and Converting Arrays to DataFrames
print("\n--- Task 1: Basic Pandas Functions and Converting Arrays to DataFrames ---")

# 1.1
s1_1 = pd.Series([10, 20, 30, 40, 50])

# 1.2
np_array1_2 = np.random.randint(1, 101, size=(3, 4))

# 1.3
df1_3 = pd.DataFrame(np_array1_2, columns=['A', 'B', 'C', 'D'])

print(s1_1)
print(df1_3)


# Task 2: Synthetic Data Generation for Practice
print("\n--- Task 2: Synthetic Data Generation for Practice ---")

df_sales = pd.DataFrame({
    'Date': pd.date_range('2023-01-01', periods=100),
    'Region': np.random.choice(['East', 'West', 'North', 'South'], 100),
    'Product': np.random.choice(['Laptop', 'Mouse', 'Keyboard', 'Monitor'], 100),
    'Sales': np.random.randint(100, 1001, 100).astype(float),
    'Quantity': np.random.randint(1, 11, 100).astype(float)
})

# Introduce NaN values
sales_nan_idx = np.random.choice(df_sales.index, 5, replace=False)
qty_nan_idx = np.random.choice(df_sales.index, 3, replace=False)

df_sales.loc[sales_nan_idx, 'Sales'] = np.nan
df_sales.loc[qty_nan_idx, 'Quantity'] = np.nan

print(df_sales.head())


# Task 3: Indexing and Slicing in DataFrames
print("\n--- Task 3: Indexing and Slicing in DataFrames ---")

# 3.1
df3_1 = df_sales[['Region', 'Sales']]

# 3.2
df3_2 = df_sales[df_sales['Product'] == 'Laptop']

# 3.3
df3_3 = df_sales[
    (df_sales['Region'] == 'East') &
    (df_sales['Sales'] > 500)
]

# 3.4
monitor_index = df_sales[df_sales['Product'] == 'Monitor'].index[0]
val3_4 = df_sales.loc[monitor_index, 'Sales']

print(df3_1.head())
print(df3_2.head())
print(df3_3.head())
print("First Monitor Sales:", val3_4)


# Task 4: Data Cleaning (Handling Missing Values)
print("\n--- Task 4: Data Cleaning (Handling Missing Values) ---")

# 4.1
missing_counts4_1 = df_sales.isna().sum()

# 4.2
df4_2_filled = df_sales.copy()
df4_2_filled['Sales'] = df4_2_filled['Sales'].fillna(
    df4_2_filled['Sales'].mean()
)

# 4.3
df4_3_dropped = df_sales.dropna()

print(missing_counts4_1)
print(df4_2_filled.head())
print(df4_3_dropped.head())


# Task 5: Data Manipulation (Columns, Sorting, Grouping)
print("\n--- Task 5: Data Manipulation (Columns, Sorting, Grouping) ---")

# 5.1
df_sales['Total_Revenue'] = df_sales['Sales'] * df_sales['Quantity']

# 5.2
df5_2_sorted = df_sales.sort_values(
    by=['Date', 'Sales'],
    ascending=[True, False]
)

# 5.3
df5_3_grouped_region = df_sales.groupby('Region')[['Sales', 'Quantity']].sum()

# 5.4
df5_4_grouped_product = df_sales.groupby('Product')['Sales'].mean()

print(df_sales.head())
print("\nSales by Region:")
print(df5_3_grouped_region)

print("\nAverage Sales by Product:")
print(df5_4_grouped_product)
# Out:
# --- Intermediate Pandas Exercise ---
# Complete each task by writing the requested Pandas code.
# ------------------------------------
#
# --- Task 1: Basic Pandas Functions and Converting Arrays to DataFrames ---
# 0    10
# 1    20
# 2    30
# 3    40
# 4    50
# dtype: int64
#      A   B   C   D
# 0  100  69  99  42
# 1   76  73  36  45
# 2   11  48  39  60
#
# --- Task 2: Synthetic Data Generation for Practice ---
#         Date Region   Product  Sales  Quantity
# 0 2023-01-01   West  Keyboard  823.0      10.0
# 1 2023-01-02  South    Laptop  436.0       2.0
# 2 2023-01-03  South     Mouse  986.0       9.0
# 3 2023-01-04   West   Monitor  810.0       1.0
# 4 2023-01-05  North   Monitor  904.0       3.0
#
# --- Task 3: Indexing and Slicing in DataFrames ---
#   Region  Sales
# 0   West  823.0
# 1  South  436.0
# 2  South  986.0
# 3   West  810.0
# 4  North  904.0
#          Date Region Product  Sales  Quantity
# 1  2023-01-02  South  Laptop  436.0       2.0
# 9  2023-01-10   West  Laptop  101.0       4.0
# 11 2023-01-12   West  Laptop  734.0       9.0
# 13 2023-01-14   West  Laptop  366.0       8.0
# 30 2023-01-31   West  Laptop  913.0      10.0
#          Date Region   Product  Sales  Quantity
# 20 2023-01-21   East  Keyboard  805.0       7.0
# 38 2023-02-08   East  Keyboard  516.0      10.0
# 41 2023-02-11   East  Keyboard  825.0       8.0
# 47 2023-02-17   East   Monitor  522.0       9.0
# 53 2023-02-23   East   Monitor  945.0       2.0
# First Monitor Sales: 810.0
#
# --- Task 4: Data Cleaning (Handling Missing Values) ---
# Date        0
# Region      0
# Product     0
# Sales       5
# Quantity    3
# dtype: int64
#         Date Region   Product  Sales  Quantity
# 0 2023-01-01   West  Keyboard  823.0      10.0
# 1 2023-01-02  South    Laptop  436.0       2.0
# 2 2023-01-03  South     Mouse  986.0       9.0
# 3 2023-01-04   West   Monitor  810.0       1.0
# 4 2023-01-05  North   Monitor  904.0       3.0
#         Date Region   Product  Sales  Quantity
# 0 2023-01-01   West  Keyboard  823.0      10.0
# 1 2023-01-02  South    Laptop  436.0       2.0
# 2 2023-01-03  South     Mouse  986.0       9.0
# 3 2023-01-04   West   Monitor  810.0       1.0
# 4 2023-01-05  North   Monitor  904.0       3.0
#
# --- Task 5: Data Manipulation (Columns, Sorting, Grouping) ---
#         Date Region   Product  Sales  Quantity  Total_Revenue
# 0 2023-01-01   West  Keyboard  823.0      10.0         8230.0
# 1 2023-01-02  South    Laptop  436.0       2.0          872.0
# 2 2023-01-03  South     Mouse  986.0       9.0         8874.0
# 3 2023-01-04   West   Monitor  810.0       1.0          810.0
# 4 2023-01-05  North   Monitor  904.0       3.0         2712.0
#
# Sales by Region:
#           Sales  Quantity
# Region
# East     8197.0     112.0
# North   13395.0     125.0
# South   11351.0     122.0
# West    19352.0     177.0
#
# Average Sales by Product:
# Product
# Keyboard    574.956522
# Laptop      477.347826
# Monitor     547.964286
# Mouse       607.095238
# Name: Sales, dtype: float64
