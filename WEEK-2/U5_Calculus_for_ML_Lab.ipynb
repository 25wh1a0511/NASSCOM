# %% [markdown]
# <a href="https://colab.research.google.com/github/25wh1a0511/NASSCOM/blob/main/U5_Calculus_for_ML_Lab.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import sympy as sp

x, y = sp.symbols('x y')
sp.init_printing()
np.random.seed(42)
print('Setup complete. SymPy', sp.__version__, '| NumPy', np.__version__)
# Out:
# Setup complete. SymPy 1.14.0 | NumPy 2.0.2

# %%
def f(x):
    return x**2

h = 1e-6
slope_at_3 = (f(3 + h) - f(3)) / h
print('Numerical f\'(3):', round(slope_at_3, 4), ' (exact = 6)')
# Out:
# Numerical f'(3): 6.0  (exact = 6)

# %%
expr = x**2
deriv = sp.diff(expr, x)
print('d/dx (x**2) =', deriv)
print('Symbolic f\'(3) =', deriv.subs(x, 3))
# Out:
# d/dx (x**2) = 2*x
# Symbolic f'(3) = 6

# %%
def g(x):
    return x**3 + 2*x

# 1. Numerical derivative at x = 2 (use h = 1e-6)
# YOUR CODE HERE
h = 1e-6
slope_at_2 = (g(2 + h) - g(2)) / h
print('Numerical g\'(2):', round(slope_at_2, 4), ' (exact = 14)')

# 2. Symbolic derivative of x**3 + 2*x
# YOUR CODE HERE
deriv = sp.diff(x**3 + 2*x, x)
print('Symbolic g\'(x) =', deriv)

# 3. Evaluate the symbolic derivative at x = 2 and compare
# YOUR CODE HERE
print('Symbolic g\'(2) =', deriv.subs(x, 2))
# Out:
# Numerical g'(2): 14.0  (exact = 14)
# Symbolic g'(x) = 3*x**2 + 2
# Symbolic g'(2) = 14

# %%
f2 = x**2 + 3*x*y + y**2


print('df/dx =', sp.diff(f2, x))
print('df/dy =', sp.diff(f2, y))
# Out:
# df/dx = 2*x + 3*y
# df/dy = 3*x + 2*y

# %%
grad = [sp.diff(f2, v) for v in (x, y)]
print('grad f =', grad)


grad_at = [g.subs({x: 1, y: 2}) for g in grad]
print('grad f at (1, 2) =', grad_at)
# Out:
# grad f = [2*x + 3*y, 3*x + 2*y]
# grad f at (1, 2) = [8, 7]

# %%
h2 = x**2 * y + sp.sin(y)

# 1. dh/dx and dh/dy
# YOUR CODE HERE
print('dh/dx =', sp.diff(h2, x))
print('dh/dy =', sp.diff(h2, y))

# 2. Assemble the gradient list
# YOUR CODE HERE
print('grad h =', [sp.diff(h2, v) for v in (x, y)])

# 3. Evaluate at (x=2, y=0)  -> hint: .subs({x: 2, y: 0})
# YOUR CODE HERE
print('grad h at (2, 0) =', [g.subs({x: 2, y: 0}) for g in grad])
# Out:
# dh/dx = 2*x*y
# dh/dy = x**2 + cos(y)
# grad h = [2*x*y, x**2 + cos(y)]
# grad h at (2, 0) = [4, 6]

# %%
by_hand = sp.cos(x**2) * 2*x
by_sympy = sp.diff(sp.sin(x**2), x)

print('By hand :', by_hand)
print('By SymPy:', by_sympy)
print('Match?  ', sp.simplify(by_hand - by_sympy) == 0)
# Out:
# By hand : 2*x*cos(x**2)
# By SymPy: 2*x*cos(x**2)
# Match?   True

# %%
expr3 = (3*x + 1)**4
print('d/dx (3x+1)^4 =', sp.diff(expr3, x))
# Out:
# d/dx (3x+1)^4 = 12*(3*x + 1)**3

# %%
# y = exp(x**2 + 1);  inner = x**2 + 1, inner' = 2x, outer' = exp(inner)
expr4 = sp.exp(x**2 + 1)
print('dy/dx =', sp.diff(expr4, x))
# 1. By hand (as a SymPy expression)
# YOUR CODE HERE
print('dy/dx =', sp.diff(sp.exp(x**2 + 1), x))

# 2. With sp.diff
# YOUR CODE HERE
print('dy/dx =', sp.diff(sp.exp(x**2 + 1), x))

# 3. Confirm they match
# YOUR CODE HERE
print('Match?  ', sp.simplify(sp.diff(sp.exp(x**2 + 1), x) - sp.diff(expr4, x)) == 0)
# Out:
# dy/dx = 2*x*exp(x**2 + 1)
# dy/dx = 2*x*exp(x**2 + 1)
# dy/dx = 2*x*exp(x**2 + 1)
# Match?   True

# %%
X = np.random.randn(4, 3)
Y = np.random.randn(4, 1)
W1 = np.random.randn(3, 5) * 0.1
W2 = np.random.randn(5, 1) * 0.1

z1 = X @ W1
h  = np.maximum(0, z1)
y_hat = h @ W2
loss = ((y_hat - Y) ** 2).mean()
print('Initial loss:', round(loss, 4))
# Out:
# Initial loss: 1.6936

# %%
dy   = 2 * (y_hat - Y) / Y.size
dW2  = h.T @ dy
dh   = dy @ W2.T
dz1  = dh * (z1 > 0)
dW1  = X.T @ dz1

print('dW1 shape:', dW1.shape, '(matches W1)')
print('dW2 shape:', dW2.shape, '(matches W2)')
# Out:
# dW1 shape: (3, 5) (matches W1)
# dW2 shape: (5, 1) (matches W2)

# %%
lr = 0.1
W1 -= lr * dW1
W2 -= lr * dW2
h_new = np.maximum(0, X @ W1)
loss_new = ((h_new @ W2 - Y) ** 2).mean()
print('Loss before:', round(loss, 4))
print('Loss after :', round(loss_new, 4), '-> should be lower')
# Out:
# Loss before: 1.6936
# Loss after : 1.6524 -> should be lower

# %%
Xb = np.random.randn(6, 4)
Yb = np.random.randn(6, 1)
Wa = np.random.randn(4, 8) * 0.1     # input -> hidden
Wb = np.random.randn(8, 1) * 0.1     # hidden -> output

# 1. Forward pass: z1, h = ReLU(z1), y_hat, loss
# YOUR CODE HERE
print('Forward pass:')
z1 = Xb @ Wa
h = np.maximum(0, z1)
y_hat = h @ Wb
loss = ((y_hat - Yb) ** 2).mean()

# 2. Backward pass: dy, dWb, dh, dz1, dWa
# YOUR CODE HERE
print('Backward pass:')
dy = 2 * (y_hat - Yb) / Yb.size
dWb = h.T @ dy
dh = dy @ Wb.T
dz1 = dh * (z1 > 0)

# 3. One step with lr = 0.05; print loss before and after
# YOUR CODE HERE
print('Loss before:', round(loss, 4))
lr = 0.05
Wa -= lr * (Xb.T @ dz1)
Wb -= lr * (h.T @ dy)
# Out:
# Forward pass:
# Backward pass:
# Loss before: 0.8782

# %%
f5 = x**2 + 3*x*y + y**2
H = sp.hessian(f5, (x, y))
print('Hessian of f:')
sp.pprint(H)
# Out:
# Hessian of f:
# ⎡2  3⎤
# ⎢    ⎥
# ⎣3  2⎦

# %%
xv = 0.0
lr = 0.2
for step in range(15):
    grad = 2 * (xv - 4)
    xv = xv - lr * grad
print('Converged x:', round(xv, 3), ' (true minimum = 4)')
# Out:
# Converged x: 3.998  (true minimum = 4)

# %%
# 1. Hessian of x**4 + y**2
# YOUR CODE HERE
print('Hessian of x**4 + y**2:')
sp.pprint(sp.hessian(x**4 + y**2, (x, y)))

# 2. Gradient descent to minimise (x - 7)**2
# xv = 0.0; lr = 0.1
# for step in range(20):
#     grad = ...
#     xv = ...
# print('Final x:', xv)
# YOUR CODE HERE
print('Gradient descent to minimise (x - 7)**2:')
xv = 0.0
lr = 0.1
for step in range(20):
    grad = 2 * (xv - 7)
    xv = xv - lr * grad
# Out:
# Hessian of x**4 + y**2:
# ⎡    2   ⎤
# ⎢12⋅x   0⎥
# ⎢        ⎥
# ⎣  0    2⎦
# Gradient descent to minimise (x - 7)**2:
