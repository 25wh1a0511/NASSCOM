# %% [markdown]
# <a href="https://colab.research.google.com/github/25wh1a0511/NASSCOM/blob/main/Python_Fundamentals_Syntax%2C_Variables%2C_Data_Types%2C_and_I_O.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# A simple Python statement
print("Hello, Python!")  # This is a comment

# Indentation defines blocks
if True:
    print("This is indented correctly.")
else:
    print("This won't run.")  # Not executed
# Out:
# Hello, Python!
# This is indented correctly.

# %%
# Assign values to variables
name = "Alice"
age = 25
height = 5.6

# Print values
print("Name:", name)
print("Age:", age)
print("Height:", height)

# Variables are dynamically typed
name = 123  # Now 'name' holds an integer
print("New value of name:", name)
# Out:
# Name: Alice
# Age: 25
# Height: 5.6
# New value of name: 123

# %%
a = 10
print(type(a))
# Out:
# <class 'int'>

# %%
b = 3.14
print(type(b))
# Out:
# <class 'float'>

# %%
# String
c = "Python"
print(type(c))

# Boolean
d = True
print(type(d))

# List
e = [1, 2, 3, "four"]
print(type(e), e)

# Dictionary
f = {"name": "Alice", "age": 25}
print(type(f), f)
# Out:
# <class 'str'>
# <class 'bool'>
# <class 'list'> [1, 2, 3, 'four']
# <class 'dict'> {'name': 'Alice', 'age': 25}

# %%
# Output using print
print("Welcome to Python I/O!")
# Out:
# Welcome to Python I/O!

# %%
# Input from user (uncomment to test in interactive mode)
user_name = input("Enter your name: ")
print("Hello,", user_name)
# Out:
# Enter your name: harshavardhan
# Hello, harshavardhan

# %%
# Type casting input (interactive mode only)
user_age = int(input("Enter your age: "))
print("You will be", user_age + 1, "next year.")
# Out:
# Enter your age: 18
# You will be 19 next year.
